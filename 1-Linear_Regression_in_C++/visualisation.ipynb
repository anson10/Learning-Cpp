# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('output.csv')

# %%
df.head()
# Out:
#      x         y  predicted_y
# 0  0.0  0.564981          1.0
# 1  0.1  1.132345          1.2
# 2  0.2  1.763731          1.4
# 3  0.3  1.657168          1.6
# 4  0.4  1.807163          1.8

# %%
sns.scatterplot(x='x',y='y', data=df,color='blue')
sns.lineplot(data=df, x='x', y='predicted_y',color='red')
# plt.xlim(0, 5)
# plt.ylim(0,15)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_2557/1762773162.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
